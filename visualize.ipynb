# %%
import sys
sys.argv = ['', '--type', 'visualize', '--cfg_file', 'configs/linemod.yaml', 'test.dataset', 'LinemodOccTest', 'model', 'cat', 'cls_type', 'cat']

# %%
from run import *

# %%
# %matplotlib inline
run_visualize()
# Out:
# Load model: data/model/pvnet/cat/199.pth
# loading annotations into memory...
#   0%|          | 0/1187 [00:00<?, ?it/s]
# Done (t=0.19s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.10s)
# creating index...
# index created!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-6dfffb0ab903> in <module>
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 2 run_visualize()
#
# /pfs/rdi/cei/algo_train/gupansh/clean-pvnet/run.py in run_visualize()
#     104             output = network(batch['inp'], batch)
#     105         visualizer.visualize(output, batch)
# --> 106         input()
#     107
#     108
#
# ~/anaconda3/envs/pvnet/lib/python3.7/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     861             self._parent_ident,
#     862             self._parent_header,
# --> 863             password=False,
#     864         )
#     865
#
# ~/anaconda3/envs/pvnet/lib/python3.7/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     891             except KeyboardInterrupt:
#     892                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 893                 raise KeyboardInterrupt("Interrupted by user") from None
#     894             else:
#     895                 break
#
# KeyboardInterrupt: Interrupted by user
