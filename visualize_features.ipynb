# %%
import numpy as np
import pickle
from matplotlib import pyplot as plt

# %%
cls = 'holepuncher'
idx = 7
with open('/mbrdi/sqnap1_colomirror/gupansh/input_'+cls+'.pkl','rb') as fp:
    inp = pickle.load(fp)

# %%
plt.imshow(inp[idx])
plt.show()

# %%
with open('/mbrdi/sqnap1_colomirror/gupansh/encoder_'+cls+'.pkl','rb') as fp:
    enc = pickle.load(fp)

# %%
feat_idx = 2
channel = 10
print(enc[feat_idx][idx].shape)
plt.imshow(enc[feat_idx][idx][channel])
plt.show()
# Out:
# (128, 60, 80)

# %%
with open('/mbrdi/sqnap1_colomirror/gupansh/decoder_'+cls+'.pkl','rb') as fp:
    dec = pickle.load(fp)

# %%
feat_idx = 2
channel = 10
plt.imshow(dec[feat_idx][idx][channel])
plt.show()

# %%
# visualize segmentation, conf
with open('/mbrdi/sqnap1_colomirror/gupansh/segmentation.pkl','rb') as fp:
    seg = pickle.load(fp)
with open('/mbrdi/sqnap1_colomirror/gupansh/confidence.pkl','rb') as fp:
    conf = pickle.load(fp)

# %%
plt.imshow(seg[idx])
plt.show()

# %%
plt.imshow(conf[idx]>2)
plt.show()

# %%
plt.imshow(seg[idx]*(conf[idx]>2))
plt.show()
